# %% [markdown]
# <a href="https://colab.research.google.com/github/vmcarranzam/PDS/blob/main/Proyecto_1_Regresi%C3%B3n_lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import  sklearn
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Cargando los datos

# %%
data=np.load("/content/drive/MyDrive/Colab Notebooks/Proyecto Ciencia de Datos/proyecto_training_data.npy")
df=pd.DataFrame(data, columns=["SalePrice","OverallQual","FirstFlrSF", "TotRmsAbvGrd","YearBuilt","LotFrontage"])
df
# Out:
#       SalePrice  OverallQual  FirstFlrSF  TotRmsAbvGrd  YearBuilt  LotFrontage
# 0      208500.0          7.0       856.0           8.0     2003.0         65.0
# 1      181500.0          6.0      1262.0           6.0     1976.0         80.0
# 2      223500.0          7.0       920.0           6.0     2001.0         68.0
# 3      140000.0          7.0       961.0           7.0     1915.0         60.0
# 4      250000.0          8.0      1145.0           9.0     2000.0         84.0
# ...         ...          ...         ...           ...        ...          ...
# 1455   175000.0          6.0       953.0           7.0     1999.0         62.0
# 1456   210000.0          6.0      2073.0           7.0     1978.0         85.0
# 1457   266500.0          7.0      1188.0           9.0     1941.0         66.0
# 1458   142125.0          5.0      1078.0           5.0     1950.0         68.0
# 1459   147500.0          5.0      1256.0           6.0     1965.0         75.0
#
# [1460 rows x 6 columns]

# %% [markdown]
# ###Calculando la media de cada variable

# %%
df.mean()
# Out:
# SalePrice       180921.195890
# OverallQual          6.099315
# FirstFlrSF        1162.626712
# TotRmsAbvGrd         6.517808
# YearBuilt         1971.267808
# LotFrontage         70.049958
# dtype: float64

# %% [markdown]
# ###Calculando valores mínimos, máximos y rango de cada variable

# %%
df.min()
# Out:
# SalePrice       34900.0
# OverallQual         1.0
# FirstFlrSF        334.0
# TotRmsAbvGrd        2.0
# YearBuilt        1872.0
# LotFrontage        21.0
# dtype: float64

# %%
df.max()
# Out:
# SalePrice       755000.0
# OverallQual         10.0
# FirstFlrSF        4692.0
# TotRmsAbvGrd        14.0
# YearBuilt         2010.0
# LotFrontage        313.0
# dtype: float64

# %%
rango=(df.max())-df.min()
rango
# Out:
# SalePrice       720100.0
# OverallQual          9.0
# FirstFlrSF        4358.0
# TotRmsAbvGrd        12.0
# YearBuilt          138.0
# LotFrontage        292.0
# dtype: float64

# %% [markdown]
# ###Calculando la desviación estándar de cada variable

# %%
df.std()
# Out:
# SalePrice       79442.502883
# OverallQual         1.382997
# FirstFlrSF        386.587738
# TotRmsAbvGrd        1.625393
# YearBuilt          30.202904
# LotFrontage        24.284752
# dtype: float64

# %% [markdown]
# ###Histogramas de cada variable

# %%
o=sns.histplot(df, x="OverallQual", y="SalePrice")

# %%
f=sns.histplot(df, x="FirstFlrSF", y="SalePrice")

# %%
t=sns.histplot(df, x="TotRmsAbvGrd", y="SalePrice")

# %%
y=sns.histplot(df, x="YearBuilt", y="SalePrice")

# %%
y=sns.histplot(df, x="LotFrontage", y="SalePrice")

# %% [markdown]
# ###Calculando el coeficiente de correlación de cada variable independiente

# %%
corr= [df.SalePrice.corr(df.OverallQual),df.SalePrice.corr(df.FirstFlrSF),df.SalePrice.corr(df.TotRmsAbvGrd),df.SalePrice.corr(df.YearBuilt),df.SalePrice.corr(df.LotFrontage)]

print("Correlación entre SalePrice y OverallQual es {} %".format(corr[0]*100))
print("Correlación entre SalePrice y FirstFlrSF es {} %".format(corr[1]*100))
print("Correlación entre SalePrice y TotRmsAbvGrd es {} %".format(corr[2]*100))
print("Correlación entre SalePrice y YearBuilt es {} %".format(corr[3]*100))
print("Correlación entre SalePrice y LotFrontage es {} %".format(corr[4]*100))
# Out:
# Correlación entre SalePrice y OverallQual es 79.09816005838053 %
# Correlación entre SalePrice y FirstFlrSF es 60.585218469191446 %
# Correlación entre SalePrice y TotRmsAbvGrd es 53.37231555820281 %
# Correlación entre SalePrice y YearBuilt es 52.28973328794968 %
# Correlación entre SalePrice y LotFrontage es 35.179909657067796 %

# %%
plt.scatter(df.OverallQual,df.SalePrice)
plt.title("Corr")
# Out:
# Text(0.5, 1.0, 'Corr')
